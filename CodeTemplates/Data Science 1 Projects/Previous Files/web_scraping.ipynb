# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
import seaborn as sns

# %%
# Define the URL to scrape
url = "https://en.wikipedia.org/wiki/Elden_Ring"

# Send an HTTP GET request to the URL
response = requests.get(url)

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find the first HTML tag
    first_tag = soup.find()

    # Print the content of the first tag
    print(first_tag)

else:
    print("Error: Unable to fetch the web page.")
# Out:
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled vector-feature-custom-font-size-clientpref-disabled vector-feature-client-preferences-disabled vector-feature-typography-survey-disabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Elden Ring - Wikipedia</title>
# ...

# %%
url = "https://en.wikipedia.org/wiki/Elden_Ring"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

first_tag = soup.find()
tag_name = first_tag.name

print("Name of the first tag:", tag_name)
# Out:
# Name of the first tag: html

# %%
hyperlinks = soup.find_all('a')
num_hyperlinks = len(hyperlinks)

print("Number of hyperlinks on the page:", num_hyperlinks)
# Out:
# Number of hyperlinks on the page: 1337

# %%
fromsoft_url = 'https://en.wikipedia.org/wiki/FromSoftware'
response_fromsoft = requests.get(fromsoft_url)
fromsoft_content = response_fromsoft.text

wikipage_soup = BeautifulSoup(fromsoft_content, 'lxml')

#table = soup.fine('body', class_ = 'skin-vector skin-vector-search-vue mediawiki ltr sitedir-ltr mw-hide-empty-elt ns-0 ns-subject mw-editable page-FromSoftware rootpage-FromSoftware skin-vector-2022 action-view uls-dialog-sticky-hide vector-below-page-title').find('div', class_ = 'mw-page-container').find('div', class_ = 'mw-page-container-inner').find('div', class_ = 'mw-page-container-inner').find('div', class_ = 'mw-content-container').find('main', class_ = 'mw-body').find('div', class_ = 'vector-body ve-init-mw-desktopArticleTarget-targetContainer').find('div', class_ = 'mw-body-content mw-content-ltr').find('div', class_ = 'mw-parser-output').find('table', class_ = 'wikitable sortable jquery-tablesorter')
# Find the outermost div with class "mw-parser-output"
parser_output_div = soup.find('div', class_='mw-parser-output')

# Find the table within that div
table = parser_output_div.find('table', class_='wikitable sortable jquery-tablesorter')

print(table)
# Out:
# None

# %%
# Fetch the web page
practiceurl = 'https://www.scrapethissite.com/pages/simple/'
response = requests.get(practiceurl)
html_content = response.text

# Create a Beautiful Soup object
soup = BeautifulSoup(html_content, 'lxml')


# Extract and print all paragraph text
paragraphs = soup.find_all('h3')
for paragraph in paragraphs:
    print(paragraph.text)
# Out:
#                             Andorra
#
#
#
#                             United Arab Emirates
#
#
#
#                             Afghanistan
#
#
#
#                             Antigua and Barbuda
#
#
#
#                             Anguilla
#
#
#
#                             Albania
#
#
#
#                             Armenia
#
#
#
#                             Angola
#
#
#
#                             Antarctica
#
#
#
#                             Argentina
#
#
#
#                             American Samoa
#
#
#
#                             Austria
#
#
#
#                             Australia
#
#
#
#                             Aruba
#
#
#
#                             Åland
#
#
#
#                             Azerbaijan
#
#
#
#                             Bosnia and Herzegovina
#
#
#
#                             Barbados
#
#
#
#                             Bangladesh
#
#
#
#                             Belgium
#
#
#
#                             Burkina Faso
#
#
#
# ...

# %%
from bs4 import BeautifulSoup

# Assuming your HTML content is stored in the 'html_content' variable
soup = BeautifulSoup(html_content, 'lxml')

# Find all table tags
all_tables = soup.find_all('table')
print(all_tables[1])
# Check if there is at least one table and select the second one if it exists
if len(all_tables) > 1:
    game_table = all_tables[1]

    # Now you can work with the second table as needed
    # For example, you can further search within this second table.
else:
    print("No second table found.")
# Out:
# <table class="wikitable sortable" width="auto">
# <caption>List of games developed by FromSoftware<sup class="reference" id="cite_ref-26"><a href="#cite_note-26">[26]</a></sup>
# </caption>
# <tbody><tr>
# <th>Year
# </th>
# <th>Title
# </th>
# <th>System
# </th>
# <th>International publisher
# </th></tr>
# <tr>
# <th>1994
# </th>
# <td><i><a href="/wiki/King%27s_Field_(video_game)" title="King's Field (video game)">King's Field</a></i>
# </td>
# <td><a href="/wiki/PlayStation_(console)" title="PlayStation (console)">PlayStation</a>
# </td>
# <td class="table-na" data-sort-value="" style="background: #ececec; color: #2C2C2C; vertical-align: middle; text-align: center;">—
# </td></tr>
# <tr>
# <th>1995
# </th>
# <td><i><a href="/wiki/King%27s_Field_II" title="King's Field II">King's Field II</a></i>
# </td>
# <td>PlayStation
# </td>
# ...
