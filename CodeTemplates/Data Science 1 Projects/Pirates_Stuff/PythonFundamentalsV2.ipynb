# %%
pirates_data_1 = {"Name":["Edward Teach", "Anne Bonny", "John Rackham", "Cheung Po Tsai", "Grace O'Malley", "Mary Read", "Sayyida al Hurra", "Zheng Yi Sao", "Francis Drake", "Jean Lafitte"],
                "Year_Started": [1716, 1718, 1718, 1798, 1564, 1708, 1515, 1801, 1563, 1810],
                 "Year_Ended": [1718, 1720, 1720, 1810, 1595, 1721, 1545, 1810, 1596, 1823],
                 "Sailed" : ["Caribbean", "Caribbean", "Caribbean", "South China Sea", "British Isles", "Caribbean", "Mediterranean", "South China Sea", "Caribbean", "Gulf of Mexico"],
                 "Alias" : ["Blackbeard", None, "Calico Jack", "The Kid", "Queen of Ireland", "Mark", "Hakimat Titwan", "Ching Shih", "Sir Francis Drake", "Terror of the Gulf"]}

pirates_data_2 = {"Edward Teach" : [1716, 1718, "Caribbean", "Blackbeard"],
                  "Anne Bonny" : [1718, 1720, "Caribbean", None],
                  "John Rackham" : [1718, 1720, "Caribbean", "Calico Jack"],
                  "Cheung Po Tsai" : [1798, 1810, "South China Sea", "The Kid"],
                  "Grace O'Malley" : [1564, 1595, "British Isles", "Queen of Ireland"],
                  "Mary Read" : [1708, 1721, "Caribbean", "Mark"],
                  "Sayyida al Hurra" : [1515, 1545, "Mediterranean", "Hakimat Titwan"],
                  "Zheng Yi Sao" : [1801, 1810, "South China Sea", "Ching Shih"],
                  "Francis Drake" : [1563, 1596, "Caribbean", "Sir Francis Drake"],
                  "Jean Lafitte" : [1810, 1823, "Guluf of Mexico", "Terror of the Gulf"]}

pirates_data_3 = {
    "Alias":["Blackbeard", "Anne Bonny", "Calico Jack", "Cheung Po Tsai", "Grace O'Malley", "Mary Read", "Sayyida al Hurra", "Ching Shih", "Sir Francis Drake", "Jean Lafitte"],
    "Gender":[1, 2, 1, 1, 2, 2, 2, 2, 1, 1],
    "Death":[40, 24, 37, 39, 73, 36, 75, 69, 56, 46],
    "Pirate_Height":[6.4, 5.6, 5.6, 5.3, 5.0, 5.1, None, 5.3, 5.5, 6.2],
    "Skull_And_Crossbones":[False, True, True, False, False, True, False, False, False, False],
}


def century():
    count = 0
    for i in pirates_data_2:
        if(pirates_data_2[i][0] < 1800 and pirates_data_2[i][0] >= 1700 and pirates_data_2[i][2] == "Caribbean"):
            count += 1
    print(count)

def career():
    highest = 0
    pirate = ""
    for i in pirates_data_2:
        count = i
        if (pirates_data_2[i][1] - pirates_data_2[i][0]) > highest:
            highest = pirates_data_2[i][1] - pirates_data_2[i][0]
            pirate = pirates_data_1["Name"]
    print(highest)
    print(pirate)

def average_active():
    average = 0
    for i in pirates_data_2:
            average += pirates_data_2[i][1] - pirates_data_2[i][0]
    average /= 10
    print(average)

def combine_data():
    pirates_combined = {
    "Name": pirates_data_1["Name"].copy(),
    "Year_Started": pirates_data_1["Year_Started"].copy(),
    "Year_Ended": pirates_data_1["Year_Ended"].copy(),
    "Sailed": pirates_data_1["Sailed"].copy(),
    "Alias": pirates_data_1["Alias"].copy(),
    "Gender": pirates_data_3["Gender"].copy(),
    "Death": pirates_data_3["Death"].copy(),
    "Pirate_Height": pirates_data_3["Pirate_Height"].copy(),
    "Skull_And_Crossbones": pirates_data_3["Skull_And_Crossbones"].copy(),
}

    for name, data in pirates_data_2.items():
        if name not in pirates_combined["Name"]:
            pirates_combined["Name"].append(name)
            pirates_combined["Year_Started"].append(data[0])
            pirates_combined["Year_Ended"].append(data[1])
            pirates_combined["Sailed"].append(data[2])
            pirates_combined["Alias"].append(data[3])
    print(pirates_combined)
    
combine_data()
# Out:
# {'Name': ['Edward Teach', 'Anne Bonny', 'John Rackham', 'Cheung Po Tsai', "Grace O'Malley", 'Mary Read', 'Sayyida al Hurra', 'Zheng Yi Sao', 'Francis Drake', 'Jean Lafitte'], 'Year_Started': [1716, 1718, 1718, 1798, 1564, 1708, 1515, 1801, 1563, 1810], 'Year_Ended': [1718, 1720, 1720, 1810, 1595, 1721, 1545, 1810, 1596, 1823], 'Sailed': ['Caribbean', 'Caribbean', 'Caribbean', 'South China Sea', 'British Isles', 'Caribbean', 'Mediterranean', 'South China Sea', 'Caribbean', 'Gulf of Mexico'], 'Alias': ['Blackbeard', None, 'Calico Jack', 'The Kid', 'Queen of Ireland', 'Mark', 'Hakimat Titwan', 'Ching Shih', 'Sir Francis Drake', 'Terror of the Gulf'], 'Gender': [1, 2, 1, 1, 2, 2, 2, 2, 1, 1], 'Death': [40, 24, 37, 39, 73, 36, 75, 69, 56, 46], 'Pirate_Height': [6.4, 5.6, 5.6, 5.3, 5.0, 5.1, None, 5.3, 5.5, 6.2], 'Skull_And_Crossbones': [False, True, True, False, False, True, False, False, False, False]}
