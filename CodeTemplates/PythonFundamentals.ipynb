# %%
names =  ["Blackbeard", "Anne Bonny", "Calico Jack", "Cheung Po Tsai", "Grace O'Malley", "Mary Read", "Sayyida al Hurra", "Ching Shih", "Sir Francis Drake", "Jean Lafitte"]
gender = [1, 2, 1, 1, 2, 2, 2, 2, 1, 1,] #     1 = Male 2 = female
death_age = [40, 24, 37, 39, 73, 36, 75, 69, 56, 46]
height = [6.4, 5.6, 5.6, 5.3, 5.0, 5.1, None, 5.3, 5.5, 6.2] #0 = N/A
skull_crossbones = [False, True, True, False, False, True, False, False, False, False]
dataset = [names, gender, death_age, height, skull_crossbones]

pirate_data = {
    "pirate_name":["Blackbeard", "Anne Bonny", "Calico Jack", "Cheung Po Tsai", "Grace O'Malley", "Mary Read", "Sayyida al Hurra", "Ching Shih", "Sir Francis Drake", "Jean Lafitte"],
    "gender":[1, 2, 1, 1, 2, 2, 2, 2, 1, 1],
    "death":[40, 24, 37, 39, 73, 36, 75, 69, 56, 46],
    "pirate_height":[6.4, 5.6, 5.6, 5.3, 5.0, 5.1, None, 5.3, 5.5, 6.2],
    "skull":[False, True, True, False, False, True, False, False, False, False],
}

def front_to_back():
    for i in range(1,2):
        print(dataset[0][-1 + i])
        print(dataset[1][-1 + i])
        print(dataset[2][-1 + i])
        print(dataset[3][-1 + i])
        print(dataset[4][-1 + i])

def last_column_back_to_front():
    for i in range (1, 11):
        print(dataset[4][10 - i])

def all_row_every_other():
    for i in range(1, 11):
        print(dataset[0][-1 + i])
        print(dataset[2][-1 + i])
        print(dataset[4][-1 + i])
#---------------------------------------------------------
def front_to_back_GPT():
    for i in range(len(dataset[0])):
        for data in dataset:
            print(data[i])

def last_column_back_to_front_GPT():
    for item in reversed(dataset[4]):
        print(item)

def all_row_every_other_GPT():
    for i in range(len(dataset[0])):
        if i % 2 == 0:  # Print every other row
            for data in [dataset[0], dataset[2], dataset[4]]:
                print(data[i])
#---------------------------------------------------------
def dictionary_front_to_back():
    print(pirate_data["pirate_name"][0])
    print(pirate_data["gender"][0])
    print(pirate_data["death"][0])
    print(pirate_data["pirate_height"][0])
    print(pirate_data["skull"][0])

def dictionary_back_to_front():
    #for i in range(1, 10):
        #print(pirate_data["skull"][10 - i])
    for item in reversed(pirate_data["skull"]):
        print(item)

def dictionary_all_row_every_other():
    for i in range(10):
        print(pirate_data["pirate_name"][i])
        print(pirate_data["death"][i])
        print(pirate_data["skull"][i])

def count_flag(target_list, value_wanted):
    count = 0
    for item in target_list:
        if value_wanted == target_list[item]:
            count += 1
    print(count)

def who_lives_longer(gender_list, target_gender, age_list):
    male_age = 0
    female_age = 0
    male_count = 0
    female_count = 0
    
    for i, gender in enumerate(gender_list):
        if gender == target_gender:
            male_age += age_list[i]
            male_count += 1
            print("current male age combined", male_age)
            print("Current male count", male_count)
        else:
            female_age += age_list[i]
            female_count += 1
            print("current female age combined", female_age)
            print("current female count", female_count)
    
    male_average_age = male_age / male_count if male_count > 0 else 0
    print("Average age among males:", male_average_age)
    
    female_average_age = female_age / female_count if female_count > 0 else 0
    print("Average age among females:", female_average_age)


who_lives_longer(pirate_data["gender"], 1, pirate_data["death"])
# Out:
# current male age combined 40
# Current male count 1
# current female age combined 24
# current female count 1
# current male age combined 77
# Current male count 2
# current male age combined 116
# Current male count 3
# current female age combined 97
# current female count 2
# current female age combined 133
# current female count 3
# current female age combined 208
# current female count 4
# current female age combined 277
# current female count 5
# current male age combined 172
# Current male count 4
# current male age combined 218
# Current male count 5
# Average age among males: 43.6
# Average age among females: 55.4
